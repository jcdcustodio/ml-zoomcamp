# %%
import numpy as np

# %%
u = np.array([2, 4, 5, 6])
v = np.array([1, 0, 0, 2])

# %%
2 * u
# Out:
# array([ 4,  8, 10, 12])

# %%
u + v
# Out:
# array([3, 4, 5, 8])

# %%
# Dot product
u * v
# Out:
# array([ 2,  0,  0, 12])

# %%
np.dot(u, v)
# Out:
# np.int64(14)

# %%
u.dot(v)
# Out:
# np.int64(14)
