# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("CooperUnion/cardataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/esper/.cache/kagglehub/datasets/CooperUnion/cardataset/1.archive...
# 100%|██████████| 103k/103k [00:00<00:00, 244kB/s]
# Extracting files...
# Path to dataset files: /home/esper/.cache/kagglehub/datasets/CooperUnion/cardataset/versions/1
